# %% [markdown]
# # EJERCICO 2
#
# **se cra un archivo notebook el cual tendra**
# 1. *un markdown con la descripcion del ejercicio*
# 2. *realizamos un osito hechos de simbolos con varios prints en un bloque de codigo*

# %%
print (" (\\(\\")
print (" (='.')")
print ("(,(o)(o)")
# Out:
#  (\(\
#  (='.')
# (,(o)(o)
